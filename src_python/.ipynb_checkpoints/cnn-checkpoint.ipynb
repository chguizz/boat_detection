# %% [markdown]
# # CNN for boats classification

# %%
# Import libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np
import glob
import pandas as pd
import random as rd
import os

import tensorflow as tf
import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
np.random.seed(1)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Utils function

# %%
def iou(boxA, boxB):
    """
    Compute the IOU metric
    -----------------
    Parameters:
        boxA, boxB are list of corners, top left corner and bottom right corner
        in total 4 coordinates for box [x_tl, y_tl, x_br, y_br]
    Cite:
        https://www.pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/
    """
    # computation of top left and bottom right coordinates
    # for the interseption rectangle
    xi_1 = max(boxA[0], boxB[0])
    yi_1 = max(boxA[1], boxB[1])
    xi_2 = min(boxA[2], boxB[2])
    yi_2 = min(boxA[3], boxB[3])
    
    
    # interseption area
    area_i = max(0, xi_2 - xi_1 + 1) * max(0, yi_2 - yi_1 + 1)
    
    # areas box A and box B
    area_A = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
    area_B = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)
    
    # Interseption over Union
    iou = area_i / float(area_A + area_B - area_i)
    return iou

# %%
def extract_name(absolute_path):
    i = 0
    for j in range(len(absolute_path)):
        char = absolute_path[j]
        if char == '/' or char == '\\':
            i = j
    name = absolute_path[i+1:-4]
    return name

# %%
def patch(img, box, resize=True):
    """
    It returns the corresponding patch given a bounding box and an image
    box has structure [xa, ya, xb, yb]
    (xa, ya) top left corner
    (xb, yb) bottom right corner
    """
    xa = box[0]
    ya = box[1]
    xb = box[2]
    yb = box[3]
    
    result = img[ya:yb, xa:xb]
    
    if resize:
        result = cv2.resize(result, (224,224), interpolation = cv2.INTER_LINEAR)
    return result

# %% [markdown]
# ## Loading true bounding boxes and images

# %% [markdown]
# Loading ground truth bounding boxes as pandas dataframes

# %%
gt_boxes = []
folder = "../dataset/FINAL_DATASET/TRAINING_DATASET/LABELS_TXT"
folder +=  "/*.txt"

filenames = []

for path in glob.glob(folder):
    file = extract_name(path)
    
    # We use a pandas dataframe for each image to store all bounding boxes
    if os.path.getsize(path) > 0:
        filenames.append(file)
        df = pd.read_csv(path, sep=';', header=None).iloc[:,:-1]
        series = df.iloc[:,0]
        new_column = []
        for elem in series:
            elem = elem.split(':')
            new_column.append(int(elem[-1]))
        df.iloc[:,0] = new_column

        gt_boxes.append(df)
    
print("Number of boats with labels: {}".format(len(gt_boxes)))
# Out:
# Number of boats with labels: 3106

# %% [markdown]
# Example of bounding boxes given an image:

# %%
gt_boxes[0]
# Out:
#      0    1   2    3
# 0  304  598  44  132
# 1  436  562   2   30

# %% [markdown]
# Loading images

# %%
folder = "../dataset/FINAL_DATASET/TRAINING_DATASET/IMAGES"
X_boats = []

for name in filenames:
    file = folder + "/" + name + ".png"
    X_boats.append(cv2.cvtColor(cv2.imread(file), cv2.COLOR_BGR2RGB))
    
print("Number of boats loaded: {}".format(len(X_boats)))
# Out:
# Number of boats loaded: 3106

# %% [markdown]
# ## ML Dataset creation

# %% [markdown]
# Class 1: boats

# %%
# Resizing all images
# Bilinear interpolation
image_size = (224,224)
X = []

for i in range(len(X_boats)):
    img = X_boats[i]
    for j in range(gt_boxes[i].shape[0]):
        true_box = gt_boxes[i].iloc[j,:].to_list()
        X.append(patch(img, [true_box[0], true_box[2], true_box[1], true_box[3]]))

# %%
Y = [1 for elem in X]

# %%
print("Number of class 1 samples: {}".format(len(X)))
print("Number of labels: {}".format(len(Y)))
# Out:
# Number of class 1 samples: 5089
# Number of labels: 5089

# %% [markdown]
# Class 0: others

# %%
MAX_NEGATIVES = 2

count = 0
for n in range(MAX_NEGATIVES):
    for i in range(len(X_boats)):
        img = X_boats[i]
        x = rd.randint(0, img.shape[1] - image_size[0])
        y = rd.randint(0, img.shape[0] - image_size[1])

        box = [x, y, x + image_size[0], y + image_size[1]]

        # If the bounding box chosen randomly doesn't have a IoU > 0.25
        # with any true bounding box, than we consider this a false image
        # Class 0 of no-boats
        check = True
        for j in range(gt_boxes[i].shape[0]):
            true_box = gt_boxes[i].iloc[j,:].to_list()
            if iou(box, [true_box[0], true_box[2], true_box[1], true_box[3]]) > 0.25: 
                check = False
        if check:
            X.append(patch(img, box, False))
            Y.append(0)
            count += 1

# %%
print("Number of class 0 samples: {}".format(count))
print()
print("Number of TOTAL samples: {}".format(len(X)))
print("Number of labels: {}".format(len(Y)))
# Out:
# Number of class 0 samples: 5181
#
# Number of TOTAL samples: 10270
# Number of labels: 10270

# %% [markdown]
# We convert everything into numpy array objects and split X and Y in training set, validation set and test set.

# %%
X = np.array(X)
print("X:")
print(X.shape)
print()
print("Number of samples: {}".format(X.shape[0]))
print("Image shape: ({},{})".format(X.shape[1], X.shape[2]))
print("Number of channels: {}".format(X.shape[3]))

Y = np.array(Y)
print()
print("Y:")
print(Y.shape)
# Out:
# X:
# (10270, 224, 224, 3)
#
# Number of samples: 10270
# Image shape: (224,224)
# Number of channels: 3
#
# Y:
# (10270,)

# %%
# Now we split the dataset into
# 1. training set
# 2. validation set
# 3. test set

X_train_val, X_test, y_train_val, y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, shuffle=True, random_state=1)
print("Training set: {} and {}".format(X_train.shape, y_train.shape))
print("Validation set: {} and {}".format(X_val.shape, y_val.shape))
print("Test set: {} and {}".format(X_test.shape, y_test.shape))
# Out:
# Training set: (6162, 224, 224, 3) and (6162,)
# Validation set: (2054, 224, 224, 3) and (2054,)
# Test set: (2054, 224, 224, 3) and (2054,)

# %% [markdown]
# Plot some samples:

# %%
rows = 2
cols = 10
count = 0
fig, ax = plt.subplots(rows, cols, figsize=(16,4))

for i in range(rows):
    for j in range(cols):
        ax[i,j].imshow(X_train[count,:,:,:])
        ax[i,j].set_xticks([])
        ax[i,j].set_yticks([])
        ax[i,j].set_title('class ' + str(y_train[count]))
        count += 1
plt.savefig('../report/figures/dataset_samples.png')

# %% [markdown]
# ## CLASSIFICATION

# %% [markdown]
# ## Shallow model

# %%
shallow_model = keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=[3,3], padding="same", activation="relu", input_shape=X.shape[1:]),
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Flatten(),
    keras.layers.Dense(1, activation="sigmoid")
])
shallow_model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=["accuracy"])

# %%
shallow_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 224, 224, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 32)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 401408)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 401409
# ...
# Total params: 402,305
# Trainable params: 402,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
history1 = shallow_model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data=(X_val, y_val), callbacks=[callback])
# Out:
# Train on 6162 samples, validate on 2054 samples
# Epoch 1/10
# 6162/6162 [==============================] - 115s 19ms/step - loss: 625.9276 - accuracy: 0.5996 - val_loss: 19.1936 - val_accuracy: 0.7332
# Epoch 2/10
# 6162/6162 [==============================] - 82s 13ms/step - loss: 7.3691 - accuracy: 0.8328 - val_loss: 5.1589 - val_accuracy: 0.8320
# Epoch 3/10
# 6162/6162 [==============================] - 79s 13ms/step - loss: 2.0262 - accuracy: 0.8882 - val_loss: 4.3398 - val_accuracy: 0.8374
# Epoch 4/10
# 6162/6162 [==============================] - 78s 13ms/step - loss: 1.0633 - accuracy: 0.9060 - val_loss: 3.4976 - val_accuracy: 0.8320
# Epoch 5/10
# 6162/6162 [==============================] - 78s 13ms/step - loss: 0.5213 - accuracy: 0.9331 - val_loss: 3.1889 - val_accuracy: 0.8389
# Epoch 6/10
# 6162/6162 [==============================] - 77s 13ms/step - loss: 0.4985 - accuracy: 0.9352 - val_loss: 3.1372 - val_accuracy: 0.8535
# Epoch 7/10
# ...

# %% [markdown]
# Perfomance on the test set:

# %%
scores = shallow_model.evaluate(X_test, y_test, verbose=2)
print("%s: %.2f%%" % (shallow_model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 84.71%

# %% [markdown]
# ## Deep model 1

# %%
deep_model1 = keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=[3,3], activation='relu', input_shape=X.shape[1:]),
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Conv2D(filters=16, kernel_size=[2,2], activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(1, activation="sigmoid", kernel_regularizer=tf.keras.regularizers.l2(0.01))
  ])
deep_model1.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])
  
print(deep_model1.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 110, 110, 16)      2064
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 55, 55, 16)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 48400)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 48401
# ...
# Total params: 51,361
# Trainable params: 51,361
# Non-trainable params: 0
# ...

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
history2 = deep_model1.fit(X_train, y_train, epochs=10, batch_size=128, validation_data=(X_val, y_val), callbacks=[callback])
# Out:
# Train on 6162 samples, validate on 2054 samples
# Epoch 1/10
# 6162/6162 [==============================] - 99s 16ms/step - loss: 16.3317 - accuracy: 0.6662 - val_loss: 0.5564 - val_accuracy: 0.8087
# Epoch 2/10
# 6162/6162 [==============================] - 99s 16ms/step - loss: 0.4262 - accuracy: 0.8504 - val_loss: 0.5376 - val_accuracy: 0.8393
# Epoch 3/10
# 6162/6162 [==============================] - 99s 16ms/step - loss: 0.2898 - accuracy: 0.9088 - val_loss: 0.5560 - val_accuracy: 0.8218
# Epoch 4/10
# 6162/6162 [==============================] - 98s 16ms/step - loss: 0.2632 - accuracy: 0.9179 - val_loss: 0.5737 - val_accuracy: 0.8350
# Epoch 5/10
# 6162/6162 [==============================] - 100s 16ms/step - loss: 0.1959 - accuracy: 0.9473 - val_loss: 0.7020 - val_accuracy: 0.8588

# %% [markdown]
# Perfomance on the test set:

# %%
scores = deep_model1.evaluate(X_test, y_test, verbose=2)
print("%s: %.2f%%" % (deep_model1.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 84.71%

# %% [markdown]
# ## Deep model 2

# %%
deep_model2 = keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=[3,3], activation='relu', input_shape=X.shape[1:]),
    keras.layers.Conv2D(filters=16, kernel_size=[3,3], activation='relu'),
    keras.layers.MaxPool2D(pool_size=[2,2]),
    keras.layers.Conv2D(filters=8, kernel_size=[2,2], activation='relu'),
    keras.layers.Conv2D(filters=4, kernel_size=[2,2], activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(1, activation="sigmoid", kernel_regularizer=tf.keras.regularizers.l2(0.01))
  ])
deep_model2.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])
  
print(deep_model2.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 220, 220, 16)      4624
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 109, 109, 8)       520
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 108, 108, 4)       132
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 54, 54, 4)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 11664)             0
# ...

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
history3 = deep_model2.fit(X_train, y_train, epochs=10, batch_size=128, validation_data=(X_val, y_val), callbacks=[callback])
# Out:
# Train on 6162 samples, validate on 2054 samples
# Epoch 1/10
# 6162/6162 [==============================] - 237s 38ms/step - loss: 3.0530 - accuracy: 0.5290 - val_loss: 0.7155 - val_accuracy: 0.5969
# Epoch 2/10
# 6162/6162 [==============================] - 236s 38ms/step - loss: 0.6770 - accuracy: 0.6438 - val_loss: 0.6671 - val_accuracy: 0.6548
# Epoch 3/10
# 6162/6162 [==============================] - 237s 39ms/step - loss: 0.6148 - accuracy: 0.6975 - val_loss: 0.6028 - val_accuracy: 0.7201
# Epoch 4/10
# 6162/6162 [==============================] - 238s 39ms/step - loss: 0.5634 - accuracy: 0.7381 - val_loss: 0.5725 - val_accuracy: 0.7361
# Epoch 5/10
# 6162/6162 [==============================] - 237s 38ms/step - loss: 0.5417 - accuracy: 0.7751 - val_loss: 0.5592 - val_accuracy: 0.7824
# Epoch 6/10
# 6162/6162 [==============================] - 236s 38ms/step - loss: 0.4983 - accuracy: 0.8044 - val_loss: 0.5190 - val_accuracy: 0.7843
# Epoch 7/10
# ...

# %% [markdown]
# Perfomance on the test set:

# %%
scores = deep_model2.evaluate(X_test, y_test, verbose=2)
print("%s: %.2f%%" % (deep_model2.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 85.00%

# %% [markdown]
# ## Analysis

# %% [markdown]
# Plots

# %%
fig, ax = plt.subplots(2,1, figsize=(8,10))
# ------------ shallow model
ax[0].plot(history1.epoch,history1.history['loss'], label="loss sw", color='k', marker='.', linestyle='--')
ax[0].plot(history1.epoch,history1.history['val_loss'], label="val_loss sw", color='k', marker='.', linestyle='-')
# ------------ deep model 1
ax[0].plot(history2.epoch,history2.history['loss'], label="loss dp1", color='royalblue', marker='.', linestyle='--')
ax[0].plot(history2.epoch,history2.history['val_loss'], label="val_loss dp1", color='royalblue', marker='.', linestyle='-')
# ------------ deep model 2
ax[0].plot(history3.epoch,history3.history['loss'], label="loss dp2", color='firebrick', marker='.', linestyle='--')
ax[0].plot(history3.epoch,history3.history['val_loss'], label="val_loss dp2", color='firebrick', marker='.', linestyle='-')
ax[0].legend()
ax[0].title.set_text('Binary crossentropy')

# ------------ shallow model
ax[1].plot(history1.epoch,history1.history['accuracy'], label="accuracy sw", color='k', marker='.', linestyle='--')
ax[1].plot(history1.epoch,history1.history['val_accuracy'], label="val_accuracy sw", color='k', marker='.', linestyle='-')
# ------------ deep model 1
ax[1].plot(history2.epoch,history2.history['accuracy'], label="accuracy dp1", color='royalblue', marker='.', linestyle='--')
ax[1].plot(history2.epoch,history2.history['val_accuracy'], label="val_accuracy dp1", color='royalblue', marker='.', linestyle='-')
# ------------ deep model 3
ax[1].plot(history3.epoch,history3.history['accuracy'], label="accuracy dp2", color='firebrick', marker='.', linestyle='--')
ax[1].plot(history3.epoch,history3.history['val_accuracy'], label="val_accuracy dp2", color='firebrick', marker='.', linestyle='-')
ax[1].legend()
ax[1].title.set_text('Accuracy')

plt.savefig('../report/figures/loss_acc.png')

plt.show()

# %%
from sklearn.metrics import roc_curve
y_pred = shallow_model.predict(X_test)
fpr1, tpr1, th1 = roc_curve(y_test, y_pred)

y_pred = deep_model1.predict(X_test)
fpr2, tpr2, th2 = roc_curve(y_test, y_pred)

y_pred = deep_model2.predict(X_test)
fpr3, tpr3, th3 = roc_curve(y_test, y_pred)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(fpr1, tpr1, label="shallow model", color='k', marker='.', linestyle='-')
ax.plot(fpr2, tpr2, label="deep model 1", color='royalblue', marker='.', linestyle='-')
ax.plot(fpr3, tpr3, label="deep model 2", color='firebrick', marker='.', linestyle='-')
ax.plot([0, 1], [0, 1], color='k', linestyle='--')
ax.legend()
ax.title.set_text('ROC curve')
ax.grid(linestyle=':', linewidth=1)

plt.savefig('../report/figures/roc_curve.png')

plt.show()

# %% [markdown]
# Using earlystopping technique we monitor the validation loss in order to stop the model if it has a decrease in performance for at leaast 3  epochs (patience = 3). Taking into account this, we can see that for deep model 2 at his maximum the gap between the accuracy of the training and the validation set is the smallest among all CNN architectures considered so far. Deep model 2 results to be the best also looking at the ROC curve. Therefore deep model 2 is the chosen model for boat classification.

# %%
deep_model2.save("cnn.pb")

# %%
v = tf.Variable(0, name='deep_model2')
sess = tf.compat.v1.Session()
tf.io.write_graph(sess.graph_def, './', 'cnn.pbtxt')
# Out:
# './cnn.pbtxt'
